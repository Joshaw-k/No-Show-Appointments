# %% [markdown]
# # Project: Medical Appointments No-Show
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# <li><a href="#references">References</a></li>
# </ul>

# %% [markdown]
# # <a id='intro'></a>
# ## Introduction
#
# Patient no-shows are long-standing problems affecting aid utilization and posing risks to the first-class healthcare services. They also lead to a loss of predicted revenue, specifically in services where resources are expensive and in top-notch calls.
# In this case study we are going to be working on a public dataset ([Medical Appoinments No-Show](https://www.kaggle.com/datasets/joniarroba/noshowappointments)) stored on kaggle, which will help us to ask intelligent questions, analyze the dataset and then communicate with visuals for proper interactions and understanding.
#
# The medical appointments no show data contains over one hundred thousand medical appointments with fourteen attributes associated with the data.
# *  **PatientId** - Identification of a patient
# *  **AppointmentID** - Identification of each appointment
# *  **Gender** - Male or Female . Female is the greater proportion, woman takes way more care of they health in comparison to man.
# *  **ScheduledDay** - The day of the actuall appointment, when they have to visit the doctor.
# *  **AppointmentDay** - The day someone called or registered the appointment, this is before appointment of course.
# *  **Age** - How old is the patient.
# *  **Neighbourhood** - Where the appointment takes place.
# *  **Scholarship** - True of False
# *  **Hipertension** - True of False
# *  **Diabetes** - True of False
# *  **Alcoholism** - True of False
# *  **Handcap** - True of False
# *  **SMS_received** - 1 or more messages sent to the patient.
# *  **No-show** - True of False
# *  **Neighbourhood** - True or False.
#
# This analysis aims at discovering the possible reasons behind the high rate of patients not showing up on their scheduled day and to also discover some unpopular trends that will benefit healthcare services. As we go further into the analysis process we must know that this is a tentative approach towards exploring this dataset and there will always be room for improvement

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# >In this section of the report, we will load in the data, check for cleanliness, and then trim and clean your dataset for analysis. The steps followed in this document we taken carefully to justify my data cleaning for this analysis.

# %%
# let's load the packages needed for this data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats 

# let's load the data
no_show_df = pd.read_csv('no_show.csv')

# %%
# Number of samples in the dataset
no_show_df.shape
# Out:
# (110527, 14)

# %% [markdown]
# > We have 110527 observations and 14 attributes

# %%
# let's see the datatypes of the attributes
no_show_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %% [markdown]
# > When checking the datatypes of the dataset i noticed the ParentId, ScheduledDay and AppointmentDay had incorrect datatypes. So let's clean those attributes

# %%
# Let's change the datatype of the No-show
def noshow(ans):
    if ans == 'Yes':
        ans = 1
    else:
        ans = 0
    return ans    
no_show_df['No-show'] = no_show_df['No-show'].apply(noshow)
no_show_df['No-show'] = no_show_df['No-show'].astype('int64')

#Let's change the datatype of the ParentId and AppointmentId
no_show_df['PatientId'] = no_show_df['PatientId'].astype('int64')
no_show_df['PatientId'] = no_show_df['PatientId'].astype(str)
no_show_df['AppointmentID'] = no_show_df['AppointmentID'].astype(str)

no_show_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  object
#  1   AppointmentID   110527 non-null  object
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  int64
# dtypes: int64(8), object(6)
# memory usage: 11.8+ MB

# %%
# let's change the datatype of the ScheduledDay and AppointmentDay

no_show_df['ScheduledDay'] = pd.to_datetime(no_show_df['ScheduledDay'])
no_show_df['AppointmentDay'] = pd.to_datetime(no_show_df['AppointmentDay']).dt.date

# let's add a new attributes named ScheduledTime from ScheduledDay
no_show_df['ScheduledTime'] = pd.to_datetime(no_show_df['ScheduledDay']).dt.time

# lets add a new attribute named AwaitingDays from the days between AppointmentDay and ScheduledDay
no_show_df['ScheduledDay'] = pd.to_datetime(no_show_df['ScheduledDay']).dt.date
no_show_df['AwaitingDays'] = ((no_show_df['AppointmentDay'] - no_show_df['ScheduledDay'])/np.timedelta64(1,'D'))
no_show_df['AwaitingDays'] = no_show_df['AwaitingDays'].astype('int64')

no_show_df
# Out:
#               PatientId AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0        29872499824296       5642903      F   2016-04-29     2016-04-29   62
# 1       558997776694438       5642503      M   2016-04-29     2016-04-29   56
# 2         4262962299951       5642549      F   2016-04-29     2016-04-29   62
# 3          867951213174       5642828      F   2016-04-29     2016-04-29    8
# 4         8841186448183       5642494      F   2016-04-29     2016-04-29   56
# ...                 ...           ...    ...          ...            ...  ...
# 110522    2572134369293       5651768      F   2016-05-03     2016-06-07   56
# 110523    3596266328735       5650093      F   2016-05-03     2016-06-07   51
# 110524   15576631729893       5630692      F   2016-04-27     2016-06-07   21
# 110525   92134931435557       5630323      F   2016-04-27     2016-06-07   38
# 110526  377511518121127       5629448      F   2016-04-27     2016-06-07   54
#
# ...

# %%
# let's detect the number duplicated rows in the dataset
no_show_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# > There are no duplicated rows in these dataset

# %%
# let's look for missing values in the dataset
no_show_df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %% [markdown]
# > There are no missing values in this dataset. These dataset is looking clean.

# %%
# let's see the number of unique values in each attribute of the dataset
no_show_df.nunique()
# Out:
# PatientId          62299
# AppointmentID     110527
# Gender                 2
# ScheduledDay      103549
# AppointmentDay        27
# Age                  104
# Neighbourhood         81
# Scholarship            2
# Hipertension           2
# Diabetes               2
# Alcoholism             2
# Handcap                5
# SMS_received           2
# No-show                2
# dtype: int64

# %% [markdown]
# ##### Let's check the dataset for some obvious outliers

# %%
# let's check the Gender attribute
no_show_df['Gender'].value_counts()
# Out:
# F    71840
# M    38687
# Name: Gender, dtype: int64

# %% [markdown]
# > We can see that female observations is 2X that of the males in this dataset

# %%
# let's check the Age attribute
no_show_df['Age'].value_counts()
# Out:
#  0      3539
#  1      2273
#  52     1746
#  49     1652
#  53     1651
#         ...
#  115       5
#  100       4
#  102       2
#  99        1
# -1         1
# Name: Age, Length: 104, dtype: int64

# %% [markdown]
# > We can see that we've identified a negative and some very high ages which is possible but not common in these generation, So we would drop them as outliers

# %%
# let's drop the ages with outliers

no_show_df = no_show_df[(no_show_df['Age'] > 0) & (no_show_df['Age'] <= 95)]
no_show_df['Age'].value_counts()
# Out:
# 1     2273
# 52    1746
# 49    1652
# 53    1651
# 56    1635
#       ...
# 92      86
# 91      66
# 93      53
# 94      33
# 95      24
# Name: Age, Length: 95, dtype: int64

# %%
no_show_df['Handcap'].value_counts()
# Out:
# 0    104710
# 1      2033
# 2       182
# 3        13
# 4         3
# Name: Handcap, dtype: int64

# %% [markdown]
# > In the description of the dataset, the attribute "Handicap" describes the degree at which a patient is handicapped

# %%
# During the data cleaning i noticed some wrong spelling of the column labels

no_show_df.rename(columns = {'Hipertension':'Hypertension','No-show':'No_show','Handcap':'Handicap'}, inplace=True)
no_show_df
# Out:
#               PatientId AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0        29872499824296       5642903      F   2016-04-29     2016-04-29   62
# 1       558997776694438       5642503      M   2016-04-29     2016-04-29   56
# 2         4262962299951       5642549      F   2016-04-29     2016-04-29   62
# 3          867951213174       5642828      F   2016-04-29     2016-04-29    8
# 4         8841186448183       5642494      F   2016-04-29     2016-04-29   56
# ...                 ...           ...    ...          ...            ...  ...
# 110522    2572134369293       5651768      F   2016-05-03     2016-06-07   56
# 110523    3596266328735       5650093      F   2016-05-03     2016-06-07   51
# 110524   15576631729893       5630692      F   2016-04-27     2016-06-07   21
# 110525   92134931435557       5630323      F   2016-04-27     2016-06-07   38
# 110526  377511518121127       5629448      F   2016-04-27     2016-06-07   54
#
# ...

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# > Now that we've trimmed and cleaned your data, we're ready to move on to exploration. Compute statistics and create visualizations with the goal of addressing the research questions that we posed in the Introduction section.

# %% [markdown]
# ### Univariate Data Analysis
# > In this segment of exploratory data analysis we are going to compute statistics and create visualizations between a single variable. We are going to summarize and describe the variable using statistical expressoins.

# %%
# let's see the univariate statistics of each individual variable

no_show_df.describe()
# Out:
#                  Age    Scholarship   Hypertension       Diabetes  \
# count  106941.000000  106941.000000  106941.000000  106941.000000
# mean       38.289879       0.101074       0.203598       0.074218
# std        22.435165       0.301429       0.402675       0.262127
# min         1.000000       0.000000       0.000000       0.000000
# 25%        19.000000       0.000000       0.000000       0.000000
# 50%        38.000000       0.000000       0.000000       0.000000
# 75%        56.000000       0.000000       0.000000       0.000000
# max        95.000000       1.000000       1.000000       1.000000
#
#           Alcoholism       Handicap   SMS_received        No_show
# count  106941.000000  106941.000000  106941.000000  106941.000000
# mean        0.031419       0.022891       0.323365       0.202663
# std         0.174449       0.163820       0.467763       0.401985
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# let's create a univariate histogram chart to display the frequency of each individual variable

no_show_df.hist(figsize=(20,20))
sns.set_style("darkgrid");

# %% [markdown]
# > From the histograms above we can see that the Age and AwaitingDays chart are skewed to the right

# %%
# let's create a univariate pie chart to display the frequency of each individual variable

conditions = ['Scholarship','Hypertension','Diabetes','Alcoholism','Handicap']

# creates a function to get all 1's in each column
def condition(conditions):
    data = []
    keys = []
    for i in conditions:
        name = no_show_df[i].value_counts().name
        value = no_show_df[i].value_counts().values[1]
        keys.append(name)
        data.append(value)
    return keys,data


plt.figure(figsize=(14,8))
plt.pie(condition(conditions)[1],labels=condition(conditions)[0],autopct='%.0f%%')
plt.title('Frequency of each Patient Condition',fontsize=18)
sns.set_style("darkgrid");

# %% [markdown]
# > The pie chart tells us that Hypertension patients had the most appointments (47%) in those few months followed by Students on Scholarship (24%),Diabetes patients (17%), Alcoholism patients (7%) and Handicap (4%)

# %% [markdown]
# ### Bivariate Data Analysis
# > In this segment of exploratory data analysis we are going to compute statistics and create visualizations between a two variables. We are going to summarize and describe the variable using statistical expressoins.

# %%
# let's see the correlation between bivariate variables using a heatmap

conditions = ['Age','Scholarship','Hypertension','Diabetes','Alcoholism','Handicap','SMS_received','No_show','AwaitingDays']

plt.figure(figsize=(14,8))
sns.heatmap(data =no_show_df[conditions].corr(),annot=True)
plt.title('Correlation between bivariate variables using a heatmap',fontsize=18)

plt.show()

# %% [markdown]
# From the heatmap we can see that there is a postive correlation between this groups:
# * Age and Hypertension
# * Age and Diabetes
# * Hypertension and Diabetes
# * No_show and AwaitingDays
# * No_show and SMS_received

# %%
# let's check the relationship between Age and Hypertension
sns.set_style('darkgrid')
plt.title('Relationship between Age and Hypertension',fontsize=14)
s = sns.barplot(data=no_show_df,x='Hypertension',y='Age')
s.set_xticklabels(['No','Yes'])
# Out:
# [Text(0, 0, 'No'), Text(1, 0, 'Yes')]

# %%
# let's check the relationship between Age and Diabetes

sns.set_style('darkgrid')
plt.title('Relationship between Age and Diabetes',fontsize=14)
s = sns.barplot(data=no_show_df,x='Diabetes',y='Age')
s.set_xticklabels(['No','Yes'])
# Out:
# [Text(0, 0, 'No'), Text(1, 0, 'Yes')]

# %%
# let's check the relationship between Hypertension and Diabetes
sns.set_style('darkgrid')
plt.title('Relationship between Hypertension and Diabetes',fontsize=14)
s = sns.barplot(data=no_show_df,x='Hypertension',y='Diabetes')
s.set_xticklabels(['No','Yes'])
# Out:
# [Text(0, 0, 'No'), Text(1, 0, 'Yes')]

# %%
# let's check the relationship between No_show and AwaitingDays
sns.set_style('darkgrid')
plt.title('Relationship between No_show and AwaitingDays',fontsize=14)
s = sns.barplot(data=no_show_df,x='No_show',y='AwaitingDays')
s.set_xticklabels(['No','Yes'])
# Out:
# [Text(0, 0, 'No'), Text(1, 0, 'Yes')]

# %% [markdown]
# ### Multivariate Data Analysis
# > In this segment of exploratory data analysis we are going to compute statistics and create visualizations between a multiple variables. We are going to summarize and describe the variable using statistical expressoins.

# %% [markdown]
# <a id='question1'></a>
# ### Questions Asked
#
# #### What is total number of No show compared between the gender of the patient and the number of awaiting days ?

# %%
# let's create a bar plot to show total number of No show compared between the gender and the awaiting days
plt.figure(figsize=(12,5))
s= sns.barplot(data=no_show_df,x= 'Gender',y='AwaitingDays',hue='No_show')
s.set_xticklabels(['Female','Male'])
L=plt.legend(title='No Show')
L.get_texts()[0].set_text('No')
L.get_texts()[1].set_text('Yes')
plt.grid()
plt.title('Total number of No show compared between the gender and awaiting days',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Total number of No show compared between the gender and awaiting days')

# %% [markdown]
# > From this graph you can see that the proportion of No Show for Female is almost the same as for male against the number of awaiting days, which implies that there is always a high probability of No Show irrespective of the gender.

# %% [markdown]
# <a href="question2"></a>
# #### What is distribution between the probability of No show and mutiple variables in the dataset ?

# %%
# let's create a bar plot to show distribution between the probability of No show and mutiple variables in the dataset

# prob_of_noshow is a function that creates a dataframe containing probability of No show and mutiple variables in the dataset
def prob_of_noshow(group_by):
    rows = []
    for item in group_by:
        for level in no_show_df[item].unique():
            if level == 1:
                row = {'Condition': item}
                total = len(no_show_df[no_show_df[item] == level])
                n = len(no_show_df[(no_show_df[item] == level) & (no_show_df['No_show'] == 1)])
                row.update({'Level': level, 'Probability of No Show': n / total})
                rows.append(row)
    return pd.DataFrame(rows)

# bar plot graph
plt.figure(figsize=(12,5))
sns.barplot(data = prob_of_noshow(['Diabetes', 'Alcoholism', 'Hypertension','Scholarship','SMS_received']),x = 'Condition', y = 'Probability of No Show')
plt.title('Probability of No show and mutiple variables in the dataset',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Probability of No show and mutiple variables in the dataset')

# %% [markdown]
# <a href="question3"></a>
# #### What is the distribution between No show and age of the patients ?

# %%
# let's create a bar plot to show distribution between No Show and age of the patients in the dataset

# The age_range function is used to categeorize the ages into groups since there are many unique age
def age_range(age):
    if age >= 60:
        return 'Senior Adult'
    elif (age >= 19) & (age < 60):
        return 'Adult'
    elif (age >= 13) & (age < 19):
        return 'Adolescence'
    else:
        return 'child'
no_show_df['Age_range'] = no_show_df['Age'].apply(age_range)

# bar plot graph
plt.figure(figsize=(12,5))
sns.barplot(data=no_show_df,x= 'Age_range',y='No_show')
plt.ylabel('No Show')
plt.xlabel('Age Group')
plt.title('distribution between No show and age of the patients',fontsize=18)
# Out:
# Text(0.5, 1.0, 'distribution between No show and age of the patients')

# %% [markdown]
# <a href="question4"></a>
# #### Is there a correlation between Scheduled Day of appointment and number of awaiting days

# %%
# let's create a bar plot to show correlation between Scheduled Day of appointment and number of awaiting days

# Scatter plot graph
plt.figure(figsize=(20,5))
sns.scatterplot(data=no_show_df,x= 'ScheduledDay',y='AwaitingDays',hue='No_show')
plt.title('distribution between No show and age of the patients in the dataset',fontsize=18)
L=plt.legend(title='No Show')
L.get_texts()[0].set_text('No')
L.get_texts()[1].set_text('Yes')

# %% [markdown]
# <a href="question5"></a>
# ### Where are the locations with most No Show in the dataset ?

# %%
# let's create a bar plot to show the locations with most No Show in the dataset

# let's group by Neighbourhood
neighbourhood = no_show_df.groupby('Neighbourhood')['No_show']

# let's get the top ten most No show locations
top_neighbourhood = neighbourhood.sum().sort_values(ascending=False).head(10)
top_neighbourhood.index
# bar plot graph
plt.figure(figsize=(17,8))
s = sns.barplot(data=top_neighbourhood,x= top_neighbourhood.index,y=top_neighbourhood.values)
s.set_xticklabels(['JARDIM CAMBURI', 'MARIA ORTIZ', 'ITARARÉ', 'RESISTÊNCIA', 'CENTRO',
       'JESUS DE NAZARETH', 'JARDIM DA PENHA', 'CARATOÍRA', 'TABUAZEIRO',
       'BONFIM'])
plt.ylabel('Number of No show')
plt.title('Locations with most No Show in the dataset',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Locations with most No Show in the dataset')

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# This analysis was carried out to explore the medical appointment no-show dataset, which contains over 100k appointments and 14 features. We used this notebook to gain insight on the possible reasons behind the high rate of no-show on appointments which has affected aid utilization,first class health services and loss of predicted revenue. It is important we understand, that with the provided data and the applied methods used in this analysis, it is not possible to affirm any statement with statistical validity nor causal relations. This insights obtained through this analysis can, instead, inform and direct in-depth research on the subject, in order to validate the causes of the appointment missing and find ways to mitigate this issue.
#
# #### Limitation of the analysis
# * There is no description on how the data were acquired
# * Though they were few data to be cleaned there was still some outliers that will need to be verified for in depth research purposes
#
# #### Analysis Overview
# After rigorously going through the data i was able to ask some questions that could help gain insight on the statistics of the dataset:
# * What is total number of No show compared between the gender of the patient and the number of awaiting days ?
# > This dataset has more of female patients than male patients which means the proportion of female patients in the bar plot graph above <a href="#question1">here</a> will be more than the male. From the graph above we could see that the more the awaiting days the more patients don't show up for their appointments. what the data is driving at is that, patients should be given short awaiting days which might be more appealing to them.
# * What is distribution between the probability of Show-up and mutiple variables in the dataset ?
# > From the bar plot graph above <a href="#question2">here</a> we are able to compare multiple variables such as Diabetes, Hypertention, Alcoholism, Scholarship and SMS received with the percent of No show on appointment. The data tells us that the No show percent of diabetes patients lowest No show rate, we will need more feature to get indepth insight. The data tells us that the No show percent for Alcoholism patients is more than that of Hypertension patients, we will need more feature to get indepth insight, we can also see that patients with scholarship and sms recieved seems to have a high No show rate.
# * What is the distribution between No show and age of the patients ?
# > This graph <a href="#question3">here</a> tells us that Adolescence (13 - 19 yrs) have the highest no show rate while Senior Adults ( 60 yrs above ) have the lowest no show rate
# * Is there a correlation between Scheduled Day of appointment and number of awaiting days ?
# > From the scatter plot <a href="#question4">here</a> we detect a negative correlation between scheduled day and awaiting days, with also a growing increase in appointments after every month. The no show also tends to increase as the number of appointments increases.
# * Where are the locations with most No Show in the dataset ?
# > We were able to use a bar plot <a href="#question5">here</a> to show the top ten neighborhoods with the highest No show, with BONFIM being the highest and JARDIM CAMBURI being the last of the ten.

# %% [markdown]
# <a id='references'></a>
# ## References
#
# * Wikipedia contributors. Brazil. Wikipedia, The Free Encyclopedia. February 9, 2018, 22:06 UTC. Available at: https://en.wikipedia.org/w/index.php?title=Brazil&oldid=824851232. Accessed in May 17, 2022.
# * Kaggle. Medical Appointment No Shows. Reviewed dataset. Available at: https://www.kaggle.com/joniarroba/noshowappointments. Accessed in May 17, 2022.
# * Pandas User Guide. Available at: https://pandas.pydata.org/docs/user_guide/index.html. Accessed in May 17, 2022.
# * Pandas - Assign string values based on multiple ranges. Available at: https://stackoverflow.com/questions/69138494/pandas-assign-string-values-based-on-multiple-ranges. Accessed in May 17, 2022.
# * Pandas - Make a bar graph of 2 variables based on a dataframe. Available at: https://stackoverflow.com/questions/46794373/make-a-bar-graph-of-2-variables-based-on-a-dataframe. Accessed in May 17, 2022.
